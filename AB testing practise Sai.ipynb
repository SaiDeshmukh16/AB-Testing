# %%
import pandas as pd

# %%
	
my_list = [5, 3, 5, 1, 0, 7, 8, 1, 9, 5, 5, 7, 3, 4, 8, 9, 5, 3, 3, 2, 6, 1]

# %%
my_series = pd.Series(my_list)
my_series
# Out:
# 0     5
# 1     3
# 2     5
# 3     1
# 4     0
# 5     7
# 6     8
# 7     1
# 8     9
# 9     5
# 10    5
# 11    7
# 12    3
# 13    4
# 14    8
# 15    9
# 16    5
# 17    3
# 18    3
# 19    2
# 20    6
# 21    1
# dtype: int64

# %%
my_sample = my_series.sample(n=5)
my_sample
# Out:
# 13    4
# 8     9
# 21    1
# 6     8
# 20    6
# dtype: int64

# %%
list_of_samples = []
 
list_of_samples.append(my_series.sample(n=10, replace=True))
list_of_samples.append(my_series.sample(n=10, replace=True))
list_of_samples.append(my_series.sample(n=10, replace=True))
list_of_samples.append(my_series.sample(n=10, replace=True))
list_of_samples.append(my_series.sample(n=10, replace=True))

list_of_samples
# Out:
# [7     1
#  10    5
#  8     9
#  13    4
#  0     5
#  6     8
#  5     7
#  19    2
#  12    3
#  9     5
#  dtype: int64, 14    8
#  15    9
#  6     8
#  16    5
#  3     1
#  6     8
#  3     1
#  21    1
#  0     5
#  12    3
#  dtype: int64, 19    2
#  9     5
#  5     7
#  2     5
#  6     8
#  5     7
#  7     1
#  7     1
#  8     9
#  9     5
#  dtype: int64, 4     0
#  4     0
#  19    2
#  13    4
#  5     7
#  21    1
#  7     1
#  6     8
#  14    8
#  20    6
#  dtype: int64, 11    7
#  11    7
#  11    7
#  10    5
#  18    3
#  15    9
#  1     3
#  15    9
#  13    4
#  19    2
#  dtype: int64]

# %%
# with for loop
list_of_samples1 = []
for i in [0,1,2,3,4]:
  list_of_samples1.append(my_series.sample(n=10, replace=True))

list_of_samples1
# Out:
# [4     0
#  4     0
#  12    3
#  15    9
#  3     1
#  0     5
#  21    1
#  7     1
#  6     8
#  7     1
#  dtype: int64, 4     0
#  6     8
#  4     0
#  6     8
#  7     1
#  11    7
#  21    1
#  2     5
#  8     9
#  17    3
#  dtype: int64, 0     5
#  7     1
#  21    1
#  11    7
#  13    4
#  18    3
#  4     0
#  8     9
#  16    5
#  19    2
#  dtype: int64, 20    6
#  3     1
#  3     1
#  12    3
#  9     5
#  16    5
#  5     7
#  17    3
#  9     5
#  11    7
#  dtype: int64, 4     0
#  0     5
#  11    7
#  16    5
#  8     9
#  18    3
#  19    2
#  20    6
#  16    5
#  15    9
#  dtype: int64]

# %%
# with range()
list_of_samples = []
for i in range(1,5):
  list_of_samples.append(my_series.sample(n=10, replace=True))

list_of_samples
# Out:
# [0     5
#  11    7
#  12    3
#  16    5
#  7     1
#  16    5
#  16    5
#  3     1
#  15    9
#  19    2
#  dtype: int64, 9     5
#  1     3
#  4     0
#  9     5
#  8     9
#  11    7
#  21    1
#  2     5
#  4     0
#  2     5
#  dtype: int64, 19    2
#  16    5
#  7     1
#  7     1
#  19    2
#  1     3
#  15    9
#  10    5
#  21    1
#  9     5
#  dtype: int64, 4     0
#  19    2
#  5     7
#  13    4
#  7     1
#  3     1
#  9     5
#  5     7
#  13    4
#  6     8
#  dtype: int64]
